# %%
import numpy as np
import pandas as pd
import re

# %%
data = pd.read_csv(r"D:/Introduction-to-Data-Science-in-Python/week-2/datasets/class_grades.csv")
data.head()
# Out:
#    Prefix  Assignment  Tutorial  Midterm  TakeHome  Final
# 0       5       57.14     34.09    64.38     51.48  52.50
# 1       8       95.05    105.49    67.50     99.07  68.33
# 2       8       83.70     83.17      NaN     63.15  48.89
# 3       7         NaN       NaN    49.38    105.93  80.56
# 4       8       91.32     93.64    95.00    107.41  73.89

# %%
data.isna().head()
# Out:
#    Prefix  Assignment  Tutorial  Midterm  TakeHome  Final
# 0   False       False     False    False     False  False
# 1   False       False     False    False     False  False
# 2   False       False     False     True     False  False
# 3   False        True      True    False     False  False
# 4   False       False     False    False     False  False

# %%
data.isnull().apply(lambda col: np.mean(col), axis = 0)
# Out:
# Prefix        0.000000
# Assignment    0.070707
# Tutorial      0.030303
# Midterm       0.030303
# TakeHome      0.050505
# Final         0.030303
# dtype: float64

# %%
data.fillna("N/A").head()
# Out:
#    Prefix Assignment Tutorial Midterm TakeHome  Final
# 0       5      57.14    34.09   64.38    51.48   52.5
# 1       8      95.05   105.49    67.5    99.07  68.33
# 2       8       83.7    83.17     N/A    63.15  48.89
# 3       7        N/A      N/A   49.38   105.93  80.56
# 4       8      91.32    93.64    95.0   107.41  73.89

# %%
data.notna().head()
# Out:
#    Prefix  Assignment  Tutorial  Midterm  TakeHome  Final
# 0    True        True      True     True      True   True
# 1    True        True      True     True      True   True
# 2    True        True      True    False      True   True
# 3    True       False     False     True      True   True
# 4    True        True      True     True      True   True

# %%
data.notna().head()
# Out:
#    Prefix  Assignment  Tutorial  Midterm  TakeHome  Final
# 0    True        True      True     True      True   True
# 1    True        True      True     True      True   True
# 2    True        True      True    False      True   True
# 3    True       False     False     True      True   True
# 4    True        True      True     True      True   True

# %%
data.notnull().head()
# Out:
#    Prefix  Assignment  Tutorial  Midterm  TakeHome  Final
# 0    True        True      True     True      True   True
# 1    True        True      True     True      True   True
# 2    True        True      True    False      True   True
# 3    True       False     False     True      True   True
# 4    True        True      True     True      True   True

# %%
logs = pd.read_csv(r"D:/Introduction-to-Data-Science-in-Python/week-2/datasets/log.csv")
logs.head()
# Out:
#          time    user       video  playback position paused  volume
# 0  1469974424  cheryl  intro.html                  5  False    10.0
# 1  1469974454  cheryl  intro.html                  6    NaN     NaN
# 2  1469974544  cheryl  intro.html                  9    NaN     NaN
# 3  1469974574  cheryl  intro.html                 10    NaN     NaN
# 4  1469977514     bob  intro.html                  1    NaN     NaN

# %%
logs.shape
# Out:
# (33, 6)

# %%
logs
# Out:
#           time    user          video  playback position paused  volume
# 0   1469974424  cheryl     intro.html                  5  False    10.0
# 1   1469974454  cheryl     intro.html                  6    NaN     NaN
# 2   1469974544  cheryl     intro.html                  9    NaN     NaN
# 3   1469974574  cheryl     intro.html                 10    NaN     NaN
# 4   1469977514     bob     intro.html                  1    NaN     NaN
# 5   1469977544     bob     intro.html                  1    NaN     NaN
# 6   1469977574     bob     intro.html                  1    NaN     NaN
# 7   1469977604     bob     intro.html                  1    NaN     NaN
# 8   1469974604  cheryl     intro.html                 11    NaN     NaN
# 9   1469974694  cheryl     intro.html                 14    NaN     NaN
# 10  1469974724  cheryl     intro.html                 15    NaN     NaN
# 11  1469974454     sue  advanced.html                 24    NaN     NaN
# ...

# %%
len(logs.time.unique()) == len(logs.time)
# Out:
# False

# %%
# introduce hierarchical indexing and then sort by the indices

logs.set_index(["time", "user"]).sort_index()
# Out:
#                            video  playback position paused  volume
# time       user
# 1469974424 cheryl     intro.html                  5  False    10.0
#            sue     advanced.html                 23  False    10.0
# 1469974454 cheryl     intro.html                  6    NaN     NaN
#            sue     advanced.html                 24    NaN     NaN
# 1469974484 cheryl     intro.html                  7    NaN     NaN
# 1469974514 cheryl     intro.html                  8    NaN     NaN
# 1469974524 sue     advanced.html                 25    NaN     NaN
# 1469974544 cheryl     intro.html                  9    NaN     NaN
# 1469974554 sue     advanced.html                 26    NaN     NaN
# 1469974574 cheryl     intro.html                 10    NaN     NaN
# 1469974604 cheryl     intro.html                 11    NaN     NaN
# 1469974624 sue     advanced.html                 27    NaN     NaN
# 1469974634 cheryl     intro.html                 12    NaN     NaN
# ...

# %%
logs.set_index("time").sort_index().head()
# Out:
#               user          video  playback position paused  volume
# time
# 1469974424  cheryl     intro.html                  5  False    10.0
# 1469974424     sue  advanced.html                 23  False    10.0
# 1469974454  cheryl     intro.html                  6    NaN     NaN
# 1469974454     sue  advanced.html                 24    NaN     NaN
# 1469974484  cheryl     intro.html                  7    NaN     NaN

# %%
logs.replace(np.nan, 0).head()
# Out:
#          time    user       video  playback position paused  volume
# 0  1469974424  cheryl  intro.html                  5  False    10.0
# 1  1469974454  cheryl  intro.html                  6      0     0.0
# 2  1469974544  cheryl  intro.html                  9      0     0.0
# 3  1469974574  cheryl  intro.html                 10      0     0.0
# 4  1469977514     bob  intro.html                  1      0     0.0

# %%
logs.replace({"intro.html": "Intro.html5", "bob": "Bobby", np.nan: 0}).head()
# Out:
#          time    user        video  playback position paused  volume
# 0  1469974424  cheryl  Intro.html5                  5  False    10.0
# 1  1469974454  cheryl  Intro.html5                  6      0     0.0
# 2  1469974544  cheryl  Intro.html5                  9      0     0.0
# 3  1469974574  cheryl  Intro.html5                 10      0     0.0
# 4  1469977514   Bobby  Intro.html5                  1      0     0.0

# %%
logs.replace("^i[\w]+\.[\w]+l$", "Hello", regex = True).head()
# Out:
#          time    user  video  playback position paused  volume
# 0  1469974424  cheryl  Hello                  5  False    10.0
# 1  1469974454  cheryl  Hello                  6    NaN     NaN
# 2  1469974544  cheryl  Hello                  9    NaN     NaN
# 3  1469974574  cheryl  Hello                 10    NaN     NaN
# 4  1469977514     bob  Hello                  1    NaN     NaN

# %%
x = pd.Series([12, 34, 786, np.nan, 87, None, 0.0])
x
# Out:
# 0     12.0
# 1     34.0
# 2    786.0
# 3      NaN
# 4     87.0
# 5      NaN
# 6      0.0
# dtype: float64

# %%
x.isna()
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# 5     True
# 6    False
# dtype: bool

# %%
x.isnull()
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# 5     True
# 6    False
# dtype: bool

# %%
x.dropna()
# Out:
# 0     12.0
# 1     34.0
# 2    786.0
# 4     87.0
# 6      0.0
# dtype: float64

# %%
x.fillna(0)
# Out:
# 0     12.0
# 1     34.0
# 2    786.0
# 3      0.0
# 4     87.0
# 5      0.0
# 6      0.0
# dtype: float64

# %%
logs.replace(re.compile("^i[\w]+\.[\w]+l$"), "HTML", regex = True).head()
# Out:
#          time    user video  playback position paused  volume
# 0  1469974424  cheryl  HTML                  5  False    10.0
# 1  1469974454  cheryl  HTML                  6    NaN     NaN
# 2  1469974544  cheryl  HTML                  9    NaN     NaN
# 3  1469974574  cheryl  HTML                 10    NaN     NaN
# 4  1469977514     bob  HTML                  1    NaN     NaN

# %%
# filling NaNs using forwardfill or backwardsfill

logs.fillna(method = "ffill")
# Out:
#           time    user          video  playback position  paused  volume
# 0   1469974424  cheryl     intro.html                  5   False    10.0
# 1   1469974454  cheryl     intro.html                  6   False    10.0
# 2   1469974544  cheryl     intro.html                  9   False    10.0
# 3   1469974574  cheryl     intro.html                 10   False    10.0
# 4   1469977514     bob     intro.html                  1   False    10.0
# 5   1469977544     bob     intro.html                  1   False    10.0
# 6   1469977574     bob     intro.html                  1   False    10.0
# 7   1469977604     bob     intro.html                  1   False    10.0
# 8   1469974604  cheryl     intro.html                 11   False    10.0
# 9   1469974694  cheryl     intro.html                 14   False    10.0
# 10  1469974724  cheryl     intro.html                 15   False    10.0
# 11  1469974454     sue  advanced.html                 24   False    10.0
# ...

# %%
pd.concat([logs.fillna(method = "ffill"), logs.fillna(method = "bfill").loc[:, ["paused", "volume"]]], axis = 1)
# Out:
#           time    user          video  playback position paused  volume  \
# 0   1469974424  cheryl     intro.html                  5  False    10.0
# 1   1469974454  cheryl     intro.html                  6  False    10.0
# 2   1469974544  cheryl     intro.html                  9  False    10.0
# 3   1469974574  cheryl     intro.html                 10  False    10.0
# 4   1469977514     bob     intro.html                  1  False    10.0
# 5   1469977544     bob     intro.html                  1  False    10.0
# 6   1469977574     bob     intro.html                  1  False    10.0
# 7   1469977604     bob     intro.html                  1  False    10.0
# 8   1469974604  cheryl     intro.html                 11  False    10.0
# 9   1469974694  cheryl     intro.html                 14  False    10.0
# 10  1469974724  cheryl     intro.html                 15  False    10.0
# 11  1469974454     sue  advanced.html                 24  False    10.0
# ...
