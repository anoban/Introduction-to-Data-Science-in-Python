# %%
import numpy as np
import pandas as pd
import re

# %%
a = np.arange(8)        # 0..8
print(a)

b = a[4:6]              # 4,5
print(b)

b[:] = 40
print(a)
print(b)

c = a[4] + a[6]
print(c)
# Out:
# [0 1 2 3 4 5 6 7]
# [4 5]
# [ 0  1  2  3 40 40  6  7]
# [40 40]
# 46

# %%
string = 'ABCAC'

# %%
bool(re.match('A', string))
# Out:
# True

# %%
re.match('A', string) == True
# Out:
# False

# %%
re.split('A', string)
# Out:
# ['', 'BC', 'C']

# %%
len(re.search('A', string))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 len(re.search('A', string))
#
# TypeError: object of type 're.Match' has no len()

# %% [markdown]
# ***Consider a string s. We want to find all characters (other than A) which are followed by triple A, i.e., have AAA to the right.
# We don’t want to include the triple A in the output and just want the character immediately preceding AAA.
# Complete the code given below that would output the required result.***

# %%
def result():
    s = 'ACAABAACAAABACDBADDDFSDDDFFSSSASDAFAAACBAAAFASD'

    result = []
    # compete the pattern below
    pattern = "[^A]{1}[A]{3}"
    for item in re.finditer(pattern, s):
      # identify the group number below.
      result.append(item.group()[0])
      
    return result

# %%
result()
# Out:
# ['C', 'F', 'B']

# %%
store_1 = pd.Series([20, 15, 18, 31], index = ["Mango", "Strawberry", "Blueberry", "Vanilla"])

# %%
store_2 = pd.Series([20, 30, 15, 20, 20], index = ["Strawberry", "Vanilla", "Banana", "Mango", "Plain"])

# %%
store_1.add(store_2)
# Out:
# Banana         NaN
# Blueberry      NaN
# Mango         40.0
# Plain          NaN
# Strawberry    35.0
# Vanilla       61.0
# dtype: float64

# %%
S = pd.Series(np.arange(5), index=['a', 'b', 'c', 'd', 'e'])

# %%
S['b':'e']
# Out:
# b    1
# c    2
# d    3
# e    4
# dtype: int32

# %%
S[['b', 'c', 'd']]
# Out:
# b    1
# c    2
# d    3
# dtype: int32

# %%
S[S <= 3][S > 0]
# Out:
# b    1
# c    2
# d    3
# dtype: int32

# %%
S[1:4]
# Out:
# b    1
# c    2
# d    3
# dtype: int32

# %%
df = pd.DataFrame([[5, 6, 20], [5, 82, 28], [71, 31, 92], [67, 37, 49]], index = ["R1", "R2", "R3", "R4"], columns = ["a", "b", "c"])

# %%
df.apply(lambda x: x.max() + x.min())[1]
# Out:
# 88

# %%
data = pd.read_csv(r"D:/Introduction-to-Data-Science-in-Python/week-3/datasets/cwurData.csv")

# %%
data.unstack().unstack()
# Out:
#                                     0     \
# world_rank                             1
# institution           Harvard University
# country                              USA
# national_rank                          1
# quality_of_education                   7
# alumni_employment                      9
# quality_of_faculty                     1
# publications                           1
# influence                              1
# citations                              1
# broad_impact                         NaN
# patents                                5
# score                              100.0
# year                                2012
#
#                                                        1     \
# world_rank                                                2
# institution           Massachusetts Institute of Technology
# country                                                 USA
# national_rank                                             2
# ...

# %%
data.groupby("country").sum()
# Out:
# C:\Users\Anoban\AppData\Local\Temp\ipykernel_1700\1541192783.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data.groupby("country").sum()
#                       world_rank  national_rank  quality_of_education  \
# country
# Argentina                   5038             16                  2117
# Australia                  28844            762                 16653
# Austria                    13239            156                  7955
# Belgium                     7246            110                  4954
# Brazil                     26941            342                 12537
# Bulgaria                    1671              2                   488
# Canada                     28817           1105                 20667
# Chile                       5235             20                  2591
# ...
